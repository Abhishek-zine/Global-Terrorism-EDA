# %% [markdown]
# ## The Sparks Foundation
#
# ### Graduate Rotational Internship Programme (GRIP)
#
# #### `MAY 2023 Batch`
# #### `Candidate Name : Abhishek K Zine`
#
# ### Task_4 : Exploratory Data Analysis_Terrorism

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'G:\Data Analyst\TSF\The_Sparks_Foundation_Internship-main\The_Sparks_Foundation_Internship-main\Task_4 Exploratory Data Analysis_Terrorism\globalterrorismdb_0718dist.csv',encoding='latin1')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_208\3593254207.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'G:\Data Analyst\TSF\The_Sparks_Foundation_Internship-main\The_Sparks_Foundation_Internship-main\Task_4 Exploratory Data Analysis_Terrorism\globalterrorismdb_0718dist.csv',encoding='latin1')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %%
df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region                  region_txt  \
# 181686      182      Somalia      11          Sub-Saharan Africa
# 181687      200        Syria      10  Middle East & North Africa
# 181688      160  Philippines       5              Southeast Asia
# 181689       92        India       6                  South Asia
# 181690      160  Philippines       5              Southeast Asia
#
#               provstate           city   latitude   longitude  specificity  \
# ...

# %%
df.sample(5)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 104225  201111250017   2011      11    25        NaN         0        NaN
# 80287   200604040007   2006       4     4        NaN         0        NaN
# 108182  201205280001   2012       5    28        NaN         0        NaN
# 157991  201601220008   2016       1    21        NaN         0        NaN
# 65451   199705270006   1997       5    27        NaN         0        NaN
#
#         country  country_txt  region                  region_txt  \
# 104225       95         Iraq      10  Middle East & North Africa
# 80287        95         Iraq      10  Middle East & North Africa
# 108182        4  Afghanistan       6                  South Asia
# 157991      182      Somalia      11          Sub-Saharan Africa
# 65451       160  Philippines       5              Southeast Asia
#
#             provstate             city   latitude   longitude  specificity  \
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df = df[['iyear', 'imonth', 'iday', 'country_txt', 'region_txt', 'provstate', 'city', 
         'latitude', 'longitude', 'location', 'summary', 'attacktype1_txt', 'targtype1_txt', 
         'gname', 'motive', 'weaptype1_txt', 'nkill', 'nwound', 'addnotes']]

# %%
df.rename(columns={'iyear':'Year', 'imonth':'Month', 'iday':'Day', 'country_txt':'Country', 
                   'region_txt':'Region', 'provstate':'Province/State', 'city':'City', 
                   'latitude':'Latitude', 'longitude':'Longitude', 'location':'Location', 
                   'summary':'Summary', 'attacktype1_txt':'Attack Type', 'targtype1_txt':'Target Type', 
                   "gname":"Group Name","motive":"Motive","weaptype1_txt":"Weapon Type",
                   'nkill':'Killed', 'nwound':'Wounded', 'addnotes':'Add Notes'}, inplace=True)

# %%
df.head()
# Out:
#    Year  Month  Day             Country                       Region  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean
# 1  1970      0    0              Mexico                North America
# 2  1970      1    0         Philippines               Southeast Asia
# 3  1970      1    0              Greece               Western Europe
# 4  1970      1    0               Japan                    East Asia
#
#   Province/State           City   Latitude   Longitude Location Summary  \
# 0            NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1        Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2         Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3         Attica         Athens  37.997490   23.762728      NaN     NaN
# 4        Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                       Attack Type                  Target Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            181691 non-null  int64
#  1   Month           181691 non-null  int64
#  2   Day             181691 non-null  int64
#  3   Country         181691 non-null  object
#  4   Region          181691 non-null  object
#  5   Province/State  181270 non-null  object
#  6   City            181257 non-null  object
#  7   Latitude        177135 non-null  float64
#  8   Longitude       177134 non-null  float64
#  9   Location        55495 non-null   object
#  10  Summary         115562 non-null  object
#  11  Attack Type     181691 non-null  object
#  12  Target Type     181691 non-null  object
#  13  Group Name      181691 non-null  object
#  14  Motive          50561 non-null   object
#  15  Weapon Type     181691 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Year                   0
# Month                  0
# Day                    0
# Country                0
# Region                 0
# Province/State       421
# City                 434
# Latitude            4556
# Longitude           4557
# Location          126196
# Summary            66129
# Attack Type            0
# Target Type            0
# Group Name             0
# Motive            131130
# Weapon Type            0
# Killed             10313
# Wounded            16311
# Add Notes         153402
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 11317

# %%
df['Killed'] = df['Killed'].fillna(0)
df['Wounded'] = df['Wounded'].fillna(0)

# %%
df['Casualty'] = df['Killed'] + df['Wounded']

# %%
df.head()
# Out:
#    Year  Month  Day             Country                       Region  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean
# 1  1970      0    0              Mexico                North America
# 2  1970      1    0         Philippines               Southeast Asia
# 3  1970      1    0              Greece               Western Europe
# 4  1970      1    0               Japan                    East Asia
#
#   Province/State           City   Latitude   Longitude Location Summary  \
# 0            NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1        Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2         Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3         Attica         Athens  37.997490   23.762728      NaN     NaN
# 4        Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                       Attack Type                  Target Type  \
# ...

# %%
df.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded       Casualty
# count  1.771340e+05  181691.000000  181691.000000  181691.000000
# mean  -4.586957e+02       2.266860       2.883296       5.150156
# std    2.047790e+05      11.227057      34.309747      40.555416
# min   -8.618590e+07       0.000000       0.000000       0.000000
# ...

# %%
print('Country with the Most Attacks:', df['Country'].value_counts().idxmax())
print('City with the Most Attacks:', df['City'].value_counts().index[1])
print('Region with the Most Attacks:', df['Region'].value_counts().idxmax())
print('Year with the Most Attacks:', df['Year'].value_counts().idxmax())
print('Month with the Most Attacks:', df['Month'].value_counts().idxmax())
print('Group with the Most Attacks:', df['Group Name'].value_counts().index[1])
print('Most Attack Types:', df['Attack Type'].value_counts().idxmax())
# Out:
# Country with the Most Attacks: Iraq
# City with the Most Attacks: Baghdad
# Region with the Most Attacks: Middle East & North Africa
# Year with the Most Attacks: 2014
# Month with the Most Attacks: 5
# Group with the Most Attacks: Taliban
# Most Attack Types: Bombing/Explosion

# %% [markdown]
# #### `Finding`
#
#
# `1. Maximun People Killed in Terrorist Attack is : 1570`
#
# `2. Maximun People Wounded in Terrorist Attack is : 8191`
#
# `3. Maximun People Casualty in Terrorist Attack is : 9574`

# %%
df.hist(figsize=(15,15))
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(np.round(df.corr(), 2), annot=True)
plt.show()

# %%
attacks = df['Year'].value_counts(dropna=False).sort_index().to_frame().reset_index().rename(columns={'index':'Year', 'Year':'Attacks'}).set_index('Year')

# %%
attacks.head()
# Out:
#       Attacks
# Year
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581

# %%
attacks.tail()
# Out:
#       Attacks
# Year
# 2013    12036
# 2014    16903
# 2015    14965
# 2016    13587
# 2017    10900

# %%
attacks.sum()
# Out:
# Attacks    181691
# dtype: int64

# %%
attacks.plot(kind='bar', color='red', figsize=(25,10), fontsize=20)
plt.title('Timeline of Attacks', fontsize=25)
plt.xlabel('Attacking Years', fontsize=25)
plt.ylabel('Number of Attacks', fontsize=25)
plt.show()

# %%
attacks.plot(kind='line', color='red', figsize=(25,10), fontsize=20)
plt.title('Timeline of Attacks', fontsize=35)
plt.xlabel('Attacking Years', fontsize=25)
plt.ylabel('Number of Attacks', fontsize=25)
plt.show()

# %% [markdown]
# `1. Most Number of Attacks(16903) in 2014`
#
# `2. Least Number of Attacks(471) in 1970`
#
# `3. Record of 2017 in (10900)`

# %%
year_casualty = df[['Year', 'Casualty']].groupby('Year').sum()

# %%
year_casualty.head()
# Out:
#       Casualty
# Year
# 1970     386.0
# 1971     255.0
# 1972     975.0
# 1973     865.0
# 1974    1404.0

# %%
year_casualty.tail()
# Out:
#       Casualty
# Year
# 2013   59961.0
# 2014   85618.0
# 2015   82896.0
# 2016   74872.0
# 2017   51372.0

# %%
year_casualty.plot(kind='bar', color='red', figsize=(25,10))
plt.title("Year wise Casualties", fontsize=35)
plt.xlabel('Years', fontsize=25)
plt.xticks(fontsize=12)
plt.ylabel('Number of Casualties', fontsize=25)
plt.show()

# %%
year_casualty.plot(kind='line', color='red', figsize=(25,10))
plt.title("Year wise Casualties", fontsize=35)
plt.xlabel('Years', fontsize=25)
plt.xticks(fontsize=12)
plt.ylabel('Number of Casualties', fontsize=25)
plt.show()

# %%
year_killed = df[['Year', 'Killed']].groupby('Year').sum()

# %%
year_killed.head()
# Out:
#       Killed
# Year
# 1970   174.0
# 1971   173.0
# 1972   566.0
# 1973   370.0
# 1974   539.0

# %%
year_killed.tail()
# Out:
#        Killed
# Year
# 2013  22273.0
# 2014  44490.0
# 2015  38853.0
# 2016  34871.0
# 2017  26445.0

# %%
year_killed.plot(kind='bar', color='red', figsize=(25,10))
plt.title('Year wise People Killed in Terrorist Attacks', fontsize=35)
plt.xlabel('Killed in Years', fontsize=25)
plt.xticks(fontsize=12)
plt.ylabel('Number of Killed', fontsize=25)
plt.show()

# %%
year_killed.plot(kind='line', color='red', figsize=(25,10))
plt.title('Year wise People Killed in Terrorist Attacks', fontsize=35)
plt.xlabel('Killed in Years', fontsize=25)
plt.xticks(fontsize=12)
plt.ylabel('Number of Killed', fontsize=25)
plt.show()

# %%
pd.crosstab(df['Year'], df['Region']).plot(kind='area', figsize=(25,10))
plt.title('Years & Region Analysis of Terrorism', fontsize=35)
plt.ylabel('Number of Attacks', fontsize=25)
plt.show()

# %%
pd.crosstab(df['Year'], df['Region']).plot(kind='line', figsize=(25,10))
plt.title('Years & Region Analysis of Terrorism', fontsize=35)
plt.ylabel('Number of Attacks', fontsize=25)
plt.show()

# %% [markdown]
# `Wounded in Each Region`

# %%
year_wounded = df[['Year', 'Wounded']].groupby('Year').sum()

# %%
year_wounded.head()
# Out:
#       Wounded
# Year
# 1970    212.0
# 1971     82.0
# 1972    409.0
# 1973    495.0
# 1974    865.0

# %%
year_wounded.tail()
# Out:
#       Wounded
# Year
# 2013  37688.0
# 2014  41128.0
# 2015  44043.0
# 2016  40001.0
# 2017  24927.0

# %%
year_wounded.plot(kind='bar', color='red', figsize=(25,10))
plt.title('Wounded People in Terrorist Attacks', fontsize=35)
plt.xlabel('Years', fontsize=25)
plt.xticks(fontsize=12)
plt.ylabel('Number of Wounded', fontsize=25)
plt.show()

# %%
year_wounded.plot(kind='line', color='red', figsize=(25,10))
plt.title('Wounded People in Terrorist Attacks', fontsize=35)
plt.xlabel('Years', fontsize=25)
plt.xticks(fontsize=12)
plt.ylabel('Number of Wounded', fontsize=25)
plt.show()

# %% [markdown]
# `1970 - 2017 Terriorist Attacks in Regions`

# %%
region = pd.crosstab(df['Year'], df['Region'])

# %%
region.head()
# Out:
# Region  Australasia & Oceania  Central America & Caribbean  Central Asia  \
# Year
# 1970                        1                            7             0
# 1971                        1                            5             0
# 1972                        8                            3             0
# 1973                        1                            6             0
# 1974                        1                           11             0
#
# Region  East Asia  Eastern Europe  Middle East & North Africa  North America  \
# Year
# 1970            2              12                          28            472
# 1971            1               5                          55            247
# 1972            0               1                          53             73
# 1973            2               1                          19             64
# 1974            4               2                          42            111
#
# ...

# %%
region.tail()
# Out:
# Region  Australasia & Oceania  Central America & Caribbean  Central Asia  \
# Year
# 2013                        1                           14             7
# 2014                        9                            5             9
# 2015                       14                            1            10
# 2016                       10                            3            17
# 2017                       12                            4             7
#
# Region  East Asia  Eastern Europe  Middle East & North Africa  North America  \
# Year
# 2013           15             165                        4560             32
# 2014           43             962                        6939             37
# 2015           28             684                        6036             62
# 2016            8             134                        6115             75
# 2017            7             110                        3780             97
#
# ...

# %%
region.plot(kind='area', stacked=True, alpha=0.5, figsize=(20,10))
plt.title('Region Wise Terrorist Attacks', fontsize=30)
plt.xlabel('Years in Attacks', fontsize=20)
plt.ylabel('Number of Attacks', fontsize=20)
plt.show()

# %%
region.plot(kind='line', stacked=True, alpha=0.5, figsize=(20,10))
plt.title('Region Wise Terrorist Attacks', fontsize=30)
plt.xlabel('Years in Attacks', fontsize=20)
plt.ylabel('Number of Attacks', fontsize=20)
plt.show()

# %% [markdown]
# `1970 - 2017 Total Terrorist Attacks in Each Region`

# %%
regiontal = region.transpose()

# %%
regiontal['Total'] = regiontal.sum(axis=1)

# %%
regiontal_attack = regiontal['Total'].sort_values(ascending=False)

# %%
regiontal_attack
# Out:
# Region
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: Total, dtype: int64

# %%
regiontal_attack.plot(kind='bar', color='red', figsize=(25,10))
plt.title('1970-2017 Total Number of Attacks in Each Region', fontsize=30)
plt.xlabel('Regions')
plt.ylabel('Number of Attacks')
plt.show()

# %%
region_casualty = df[['Region', 'Casualty']].groupby('Region').sum().sort_values(by='Casualty', ascending=False)

# %%
region_casualty
# Out:
#                              Casualty
# Region
# Middle East & North Africa   351950.0
# South Asia                   242679.0
# Sub-Saharan Africa           131243.0
# South America                 45553.0
# Southeast Asia                41896.0
# Central America & Caribbean   37699.0
# North America                 26447.0
# Western Europe                25026.0
# Eastern Europe                19460.0
# East Asia                     10365.0
# Central Asia                   3009.0
# Australasia & Oceania           410.0

# %%
region_casualty.plot(kind='bar', color='red', figsize=(25,10))
plt.title('Region wise Total Casualties', fontsize=30)
plt.xlabel('Regions', fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('Number of Casualties', fontsize=15)
plt.show()

# %% [markdown]
# `People Killed in Each Region`

# %%
region_killed = df[['Region', 'Killed']].groupby('Region').sum().sort_values(by='Killed', ascending=False)

# %%
region_killed
# Out:
#                                Killed
# Region
# Middle East & North Africa   137642.0
# South Asia                   101319.0
# Sub-Saharan Africa            78386.0
# South America                 28849.0
# Central America & Caribbean   28708.0
# Southeast Asia                15637.0
# Eastern Europe                 7415.0
# Western Europe                 6694.0
# North America                  4916.0
# East Asia                      1152.0
# Central Asia                   1000.0
# Australasia & Oceania           150.0

# %% [markdown]
# `People Wounded in Each Region`

# %%
region_wounded = df[['Region', 'Wounded']].groupby('Region').sum().sort_values(by='Wounded', ascending=False)

# %%
region_wounded
# Out:
#                               Wounded
# Region
# Middle East & North Africa   214308.0
# South Asia                   141360.0
# Sub-Saharan Africa            52857.0
# Southeast Asia                26259.0
# North America                 21531.0
# Western Europe                18332.0
# South America                 16704.0
# Eastern Europe                12045.0
# East Asia                      9213.0
# Central America & Caribbean    8991.0
# Central Asia                   2009.0
# Australasia & Oceania           260.0

# %%
fig = plt.figure()
ax_0 = fig.add_subplot(1,2,1)
ax_1 = fig.add_subplot(1,2,2)

# Killed
region_killed.plot(kind='bar', color='red', figsize=(15,6),ax=ax_0)
ax0.set_title('People Killed in Each Region')
ax0.set_xlabel('Regions')
ax_0.set_ylabel('Number of People Killed')

# Wounded
region_wounded.plot(kind='bar',color='green', figsize=(15,6), ax=ax_1)
ax_1.set_title("People Wounded in Each Region")
ax_1.set_xlabel('Regions')
ax_1.set_ylabel('Number of People Wounded')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_208\639917839.py in <module>
#       5 # Killed
#       6 region_killed.plot(kind='bar', color='red', figsize=(15,6),ax=ax_0)
# ----> 7 ax0.set_title('People Killed in Each Region')
#       8 ax0.set_xlabel('Regions')
#       9 ax_0.set_ylabel('Number of People Killed')
#
# NameError: name 'ax0' is not defined

# %% [markdown]
# `Number of Terrorist Attacks in Each Country`

# %%
country_counter = df['Country'].value_counts()

# %%
country_counter.sort_values(ascending=0)

# %%
country_counter.head(10).plot(kind='bar', color='blue', figsize=(25,10))
plt.title('Country wise Terrorist Attacks', fontsize=25)
plt.xlabel('Countries', fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('Number of Terrorist Attacks', fontsize=15)
plt.show()

# %% [markdown]
# `Number People Killed in Each Country`

# %%
country_killed = df[['Country', 'Killed']].groupby('Country').sum().sort_values(by='Killed', ascending=False)

# %%
country_killed

# %%
country_wounded = df[['Country', 'Wounded']].groupby('Country').sum().sort_values(by='Wounded', ascending=False)

# %%
country_wounded

# %%
fig = plt.figure()
ax_0 = fig.add_subplot(1,2,1)
ax_1 = fig.add_subplot(1,2,2)

# Killed
country_killed[:10].plot(kind='bar', color='red', figsize=(15,6), ax=ax_0)
ax0.set_title('People Killed in Each Country')
ax0.set_xlabel('Countries')
ax0.set_ylabel('Number of People Killed')

# Wounded
country_wounded[:10].plot(kind='bar', color='green', figsize=(15,6), ax=ax_1)
ax1.set_title('People Wounded in Each Country')
ax1.set_xlabel('Countries')
ax1.set_ylabel('Number of People Wounded')

plt.show()

# %%
city = df['City'].value_counts()[1:11]

# %%
city

# %%
city.plot(kind='bar', color='blue', figsize=(25,10))
plt.title('City Wise People Attacks', fontsize=25)
plt.xlabel("Number of Cities", fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('Number of Attacks', fontsize=15)
plt.show()

# %%
city_casualty = df[['City', 'Casualty']].groupby('City').sum().sort_values(by='Casualty', ascending=False).drop('Unknown')

# %%
city_casualty

# %%
city_casualty[:10].plot(kind='bar', color='blue', figsize=(25,10))
plt.title('City Wise People Casualties', fontsize=25)
plt.xlabel('Cities', fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('Number of Casualties', fontsize=15)
plt.show()

# %%
city_killed = df[['City', 'Killed']].groupby('City').sum().sort_values(by='Killed', ascending=False).drop('Unknown')

# %%
city_killed

# %%
city_wounded = df[['City', 'Wounded']].groupby('City').sum().sort_values(by='Wounded', ascending=False).drop('Unknown')

# %%
city_wounded

# %%
fig = plt.figure()
ax_0 = fig.add_subplot(1,2,1)
ax_1 = fig.add_subplot(1,2,2)

# Killed
city_killed[:10].plot(kind='bar', color='red', figsize=(15,6), ax=ax_0)
ax0.set_title('People Killed in Each City')
ax0.set_xlabel('Cities')
ax0.set_ylabel('Number of People Killed')

# Wounded
city_wounded[:10].plot(kind='bar', color='green', figsize=(15,6), ax=ax_1)
ax1.set_title('People Wounded in Each City')
ax1.set_xlabel('Cities')
ax1.set_ylabel('Number of People Wounded')

plt.show()

# %%
gp_name = df['Group Name'].value_counts()[1:10]

# %%
gp_name

# %%
gp_name.plot(kind='bar', color='blue', figsize=(25,10))
plt.title('Group Wise Terrorist Attacks', fontsize=30)
plt.xlabel('Terrorist Groups', fontsize=25)
plt.xticks(fontsize=15)
plt.ylabel('Number of Attacks', fontsize=25)
plt.show()

# %%
grp_casu = df[['Group Name', 'Casualty']].groupby('Group Name').sum().sort_values(by='Casualty', ascending=False).drop('Unknown')

# %%
grp_casu

# %%
grp_casu.head(10).plot(kind='bar', color='blue', figsize=(25,10))
plt.title('Casualties by Each Terrorist Group', fontsize=30)
plt.xlabel('Terrorist Groups', fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('Number of Casualties', fontsize=15)
plt.show()

# %%
grp_kil = df[['Group Name', 'Killed']].groupby('Group Name').sum().sort_values(by='Killed', ascending=False).drop('Unknown')

# %%
grp_kil

# %%
grp_won = df[['Group Name', 'Wounded']].groupby('Group Name').sum().sort_values(by='Wounded', ascending=False).drop('Unknown')

# %%
grp_won

# %%
fig = plt.figure()
ax_0 = fig.add_subplot(1,2,1)
ax_1 = fig.add_subplot(1,2,2)

# Killed
grp_kil[:10].plot(kind='bar', color='red', figsize=(15,6), ax=ax_0)
ax0.set_title('People Killed by Each Terrorist Group')
ax0.set_xlabel('Terrorist Groups')
ax0.set_ylabel('Number of People Killed')

# Wounded
grp_won[:10].plot(kind='bar', color='green', figsize=(15,6), ax=ax_1)
ax1.set_title('People Wounded by Each Terrorist Group')
ax1.set_xlabel('Terrorist Groups')
ax1.set_ylabel('Number of People Wounded')
plt.show()

# %%
attacktype = df['Attack Type'].value_counts()

# %%
attacktype

# %%
attacktype.plot(kind='bar', color='blue', figsize=(25,10))
plt.title('Types of Terrorist Attacks', fontsize=25)
plt.xlabel('Attack Types', fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('Number of Attacks', fontsize=15)
plt.show()

# %% [markdown]
# `Total People Casualties (Killed + Wounded) by Each Attack Type`

# %%
attack_casu = df[['Attack Type', 'Casualty']].groupby('Attack Type').sum().sort_values(by='Casualty', ascending=False)

# %%
attack_casu

# %%
attack_casu.plot(kind='bar', color='blue', figsize=(25,10))
plt.title('Casualties in Each Terrorist Attack', fontsize=15)
plt.xlabel('Attack Types', fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('Number of Casualties', fontsize=15)
plt.show()

# %%
att_kil = df[['Attack Type', 'Killed']].groupby('Attack Type').sum().sort_values(by='Killed', ascending=False)

# %%
att_kil

# %%
att_wun = df[['Attack Type', 'Wounded']].groupby('Attack Type').sum().sort_values(by='Wounded', ascending=False)

# %%
att_wun

# %%
fig = plt.figure()
ax_0 = fig.add_subplot(1,2,1)
ax_1 = fig.add_subplot(1,2,2)

# Killed
att_kil.plot(kind='bar', color='red', figsize=(15,6), ax=ax_0)
ax0.set_title('People Killed in Each Terrorist Attack Type')
ax0.set_xlabel('Attack Types')
ax0.set_ylabel('Number of People Killed')

# Wounded
att_wun.plot(kind='bar', color='green', figsize=(15,6), ax=ax_1)
ax1.set_title('People Wounded in Each Terrorist Attack Type')
ax1.set_xlabel('Attack Types')
ax1.set_ylabel('Number of People Wounded')
plt.show()

# %%
target = df["Target Type"].value_counts()

# %%
target

# %%
target.plot(kind='bar', color='red', figsize=(25,10))
plt.title('Types of Terrorist Targets', fontsize=25)
plt.xlabel('Target Types', fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('Number of Attacks', fontsize=15)
plt.show()

# %%
targ_casu = df[['Target Type', 'Casualty']].groupby('Target Type').sum().sort_values(by='Casualty', ascending=False)

# %%
targ_casu

# %%
targ_casu.plot(kind='bar', color='red', figsize=(25,10))
plt.title('Casualties in Each Terrorist Target Attack', fontsize=25)
plt.xlabel('Target Types', fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('Number of Casualties', fontsize=15)
plt.show()

# %%
targ_kill = df[['Target Type', 'Killed']].groupby('Target Type').sum().sort_values(by='Killed', ascending=False)

# %%
targ_kill

# %%
targ_wun = df[['Target Type', 'Wounded']].groupby('Target Type').sum().sort_values(by='Wounded', ascending=False)

# %%
targ_wun

# %%
fig = plt.figure()
ax_0 = fig.add_subplot(1,2,1)
ax_1 = fig.add_subplot(1,2,2)

# Killed
targ_kill.plot(kind='bar', color='red', figsize=(17,6), ax=ax_0)
ax0.set_title('People Killed in Each Terrorist Target Attack')
ax0.set_xlabel('Target Types')
ax0.set_ylabel('Number of People Killed')

# Wounded
targ_wun.plot(kind='bar', color='green', figsize=(17,6), ax=ax_1)
ax1.set_title('People Wounded in Each Terrorist Target Attack')
ax1.set_xlabel('Target Types')
ax1.set_ylabel('Number of People Wounded')
plt.show()

# %%
grpn_coun = df[['Group Name', 'Country']].value_counts().drop('Unknown')

# %%
grpn_coun

# %%
grpn_coun.head(10).plot(kind='bar', color='green', figsize=(25,10))
plt.title('Countries With Most Terrorist Attacks By Particular Group', fontsize=15)
plt.xlabel('Terrorist Group Country', fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('Number of Attacks', fontsize=15)
plt.show()

# %%
grpn_coun_casu = df[['Group Name', 'Country', 'Casualty']].groupby(['Group Name', 'Country'], axis=0).sum().sort_values(by='Casualty', ascending=False).drop('Unknown').head(10)

# %%
grpn_coun_casu

# %%
grpn_coun_casu.plot(kind='bar', color='red', figsize=(25,10))
plt.title('Countries With Most People Casualties By Particular Group', fontsize=25)
plt.xlabel('Terrorist Group Country', fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('Number of Casualties', fontsize=15)
plt.show()

# %%
grpn_coun_kill = df[['Group Name', 'Country', 'Killed']].groupby(['Group Name', 'Country'], axis=0).sum().sort_values(by='Killed', ascending=False).drop('Unknown').head(10)

# %%
grpn_coun_kill

# %%
grpn_coun_kill.plot(kind='bar', color='red', figsize=(25,10))
plt.title('Countries With Most People Killed By Particular Terrorist Group', fontsize=25)
plt.xlabel('Terrorist Group Country',fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('Number of People Killed', fontsize=15)
plt.show()

# %%
grpn_coun_woun = df[['Group Name', 'Country', 'Wounded']].groupby(['Group Name', 'Country'], axis=0).sum().sort_values(by='Wounded', ascending=False).drop('Unknown').head(10)

# %%
grpn_coun_woun

# %%
grpn_coun_woun.plot(kind='bar', color='blue', figsize=(25,10))
plt.title('Countries With Most People Wounded By Particular Terrorist Group', fontsize=25)
plt.xlabel('Terrorist Group Country', fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('Number of People Wounded', fontsize=15)
plt.show()

# %% [markdown]
# `1970 - 2017 Total Casualties World-wide by Terrorist Attacks`

# %%
casualty = df.loc[:, 'Casualty'].sum()
casualty

# %%
kill = df.loc[:, 'Killed'].sum()
kill

# %%
wound = df.loc[:, 'Wounded'].sum()
wound

# %% [markdown]
# #### `Thank You`
